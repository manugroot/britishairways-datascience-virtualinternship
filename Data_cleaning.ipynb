# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Data CLeaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv('/content/drive/MyDrive/British Airways/reviews.csv')
df.head()
# Out:
#    Unnamed: 0                                            reviews  \
# 0           0  ✅ Trip Verified |  Very poor service, very fru...
# 1           1  Not Verified |  Generally poor. Sent to gate o...
# 2           2  Not Verified |  BA changed our prepaid seats a...
# 3           3  Not Verified |  Flew from London Heathrow to M...
# 4           4  Not Verified | I was meant to fly in January t...
#
#                            stars  month  year         country      seat_type
# 0  \n\t\t\t\t\t\t\t\t\t\t\t\t\t5  March  2023  United Kingdom  Economy Class
# 1                              1  March  2023  United Kingdom  Economy Class
# 2                              3  March  2023  United Kingdom  Economy Class
# 3                              1  March  2023  United Kingdom  Economy Class
# 4                              1  March  2023  United Kingdom  Economy Class

# %%
df.shape
# Out:
# (3498, 7)

# %%
df['verified'] = df.reviews.str.contains("Trip Verified")

# %%
df["verified"]
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3493    False
# 3494    False
# 3495    False
# 3496    False
# 3497    False
# Name: verified, Length: 3498, dtype: bool

# %%
df.head()
# Out:
#    Unnamed: 0                                            reviews  \
# 0           0  Not Verified | I was meant to fly in January t...
# 1           1  ✅ Trip Verified |  We have flown repeatedly wi...
# 2           2  ✅ Trip Verified |  I was horrified by the extr...
# 3           3  ✅ Trip Verified |  \nThe worst cabin experienc...
# 4           4  ✅ Trip Verified | First time flying with Briti...
#
#                            stars  month  year         country  \
# 0  \n\t\t\t\t\t\t\t\t\t\t\t\t\t5  March  2023  United Kingdom
# 1                              1  March  2023         Austria
# 2                              1  March  2023   United States
# 3                              3  March  2023          France
# 4                              2  March  2023           India
#
#          seat_type  verified
# 0    Economy Class     False
# 1    Economy Class      True
# 2    Economy Class      True
# 3    Economy Class      True
# 4  Premium Economy      True

# %%
df.drop(columns = df.columns[0],axis=1, inplace=True)
df.head()
# Out:
#                                              reviews  \
# 0  ✅ Trip Verified |  Very poor service, very fru...
# 1  Not Verified |  Generally poor. Sent to gate o...
# 2  Not Verified |  BA changed our prepaid seats a...
# 3  Not Verified |  Flew from London Heathrow to M...
# 4  Not Verified | I was meant to fly in January t...
#
#                            stars  month  year         country      seat_type
# 0  \n\t\t\t\t\t\t\t\t\t\t\t\t\t5  March  2023  United Kingdom  Economy Class
# 1                              1  March  2023  United Kingdom  Economy Class
# 2                              3  March  2023  United Kingdom  Economy Class
# 3                              1  March  2023  United Kingdom  Economy Class
# 4                              1  March  2023  United Kingdom  Economy Class

# %% [markdown]
# ## Review Formatting

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

lemma = WordNetLemmatizer()

df.reviews = df.reviews.str.strip("✅ Trip Verified | ")
df.reviews = df.reviews.str.strip("Not Verified | ")

corpus = []

for s in df.reviews:
  s = re.sub('[^a-zA-Z]',' ',s)
  s = s.lower()
  s = s.split()
  s = [lemma.lemmatize(word) for word in s if word not in set(stopwords.words('english'))]
  s = " ".join(s)
  corpus.append(s)

# %%
df['corpus'] = corpus

# %%
df.head()
# Out:
#                                              reviews  \
# 0  y poor service, very frustrating. Firstly my f...
# 1  Generally poor. Sent to gate on time, sat mayb...
# 2  BA changed our prepaid seats at the last minut...
# 3  Flew from London Heathrow to Marrakech. BA cha...
# 4  I was meant to fly in January to Algeria. I pa...
#
#                            stars  month  year         country      seat_type  \
# 0  \n\t\t\t\t\t\t\t\t\t\t\t\t\t5  March  2023  United Kingdom  Economy Class
# 1                              1  March  2023  United Kingdom  Economy Class
# 2                              3  March  2023  United Kingdom  Economy Class
# 3                              1  March  2023  United Kingdom  Economy Class
# 4                              1  March  2023  United Kingdom  Economy Class
#
#                                               corpus
# 0  poor service frustrating firstly flight lhr ca...
# 1  generally poor sent gate time sat maybe minute...
# 2  ba changed prepaid seat last minute charged u ...
# 3  flew london heathrow marrakech ba changed pre ...
# 4  meant fly january algeria paid ticket day mean...

# %% [markdown]
# ## Formatting Stars

# %%
df.stars.unique()
# Out:
# array(['\n\t\t\t\t\t\t\t\t\t\t\t\t\t5', '1', '3', '2', '8', '7', '10',
#        '4', '6', '5', '9', 'None'], dtype=object)

# %%
df.stars.value_counts()
# Out:
# 1       766
# 2       393
# 3       385
# 8       352
# 10      315
# 7       305
# 9       299
# 5       261
# 4       235
# 6       182
# None      5
# Name: stars, dtype: int64

# %%
df.stars = df.stars.str.strip("\n\t\t\t\t\t\t\t\t\t\t\t\t\t")

# %%
df.drop(df[df.stars == 'None'].index, axis=0,inplace = True)

# %% [markdown]
# # Checking for Null values

# %%
df.isnull().value_counts()
# Out:
# reviews  stars  month  year   country  seat_type  corpus
# False    False  False  False  False    False      False     3491
#                               True     False      False        2
# dtype: int64

# %%
df.country.isnull().value_counts()
# Out:
# False    3491
# True        2
# Name: country, dtype: int64

# %%
df.drop(df[df.country.isnull() == True].index, axis = 0, inplace = True)

# %%
df.head()
# Out:
#                                              reviews stars  month  year  \
# 0  y poor service, very frustrating. Firstly my f...     5  March  2023
# 1  Generally poor. Sent to gate on time, sat mayb...     1  March  2023
# 2  BA changed our prepaid seats at the last minut...     3  March  2023
# 3  Flew from London Heathrow to Marrakech. BA cha...     1  March  2023
# 4  I was meant to fly in January to Algeria. I pa...     1  March  2023
#
#           country      seat_type  \
# 0  United Kingdom  Economy Class
# 1  United Kingdom  Economy Class
# 2  United Kingdom  Economy Class
# 3  United Kingdom  Economy Class
# 4  United Kingdom  Economy Class
#
#                                               corpus
# 0  poor service frustrating firstly flight lhr ca...
# 1  generally poor sent gate time sat maybe minute...
# 2  ba changed prepaid seat last minute charged u ...
# 3  flew london heathrow marrakech ba changed pre ...
# 4  meant fly january algeria paid ticket day mean...

# %%
df.to_csv("/content/drive/MyDrive/British Airways/cleaned-reviews.csv")

# %%
df
# Out:
#                                                 reviews stars   month  year  \
# 0     I was meant to fly in January to Algeria. I pa...     5   March  2023
# 1     We have flown repeatedly with British Airways ...     1   March  2023
# 2     I was horrified by the extremely small seats a...     1   March  2023
# 3     \nThe worst cabin experience ever: cramped sea...     3   March  2023
# 4     First time flying with British Airways and fir...     2   March  2023
# ...                                                 ...   ...     ...   ...
# 3493  Business LHR to BKK. 747-400. First try back w...     2  August  2012
# 3494  his was a bmi Regional operated flight on a RJ...     6  August  2012
# 3495  LHR-HKG on Boeing 747 - 23/08/12. Much has bee...     7  August  2012
# 3496  Just got back from Bridgetown Barbados flying ...    10  August  2012
# 3497  LHR-JFK-LAX-LHR. Check in was ok apart from be...     1  August  2012
#
#              country        seat_type  verified  \
# 0     United Kingdom    Economy Class     False
# 1            Austria    Economy Class      True
# 2      United States    Economy Class      True
# 3             France    Economy Class      True
# 4              India  Premium Economy      True
# ...              ...              ...       ...
# 3493  United Kingdom    Economy Class     False
# 3494  United Kingdom    Economy Class     False
# 3495  United Kingdom    Economy Class     False
# 3496  United Kingdom   Business Class     False
# 3497  United Kingdom  Premium Economy     False
#
#                                                  corpus
# 0     meant fly january algeria paid ticket day mean...
# 1     flown repeatedly british airway one world alli...
# 2     horrified extremely small seat poor training c...
# 3     worst cabin experience ever cramped seat low c...
# 4     first time flying british airway first time fl...
# ...                                                 ...
# 3493  business lhr bkk first try back ba year flown ...
# 3494  bmi regional operated flight rj manchester hea...
# 3495  lhr hkg boeing much written tired old fleet go...
# 3496  got back bridgetown barbados flying british ai...
# 3497  lhr jfk lax lhr check ok apart snapped early c...
#
# [3491 rows x 8 columns]
